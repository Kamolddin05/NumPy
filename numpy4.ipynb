# %%
"""                 Aggregations: Min, Max, and Everything in Between                    """
# Out:
# '                 Aggregations: Min, Max, and Everything in Between                    '

# %%
# ----- Summing the Values in an Array ----- #

# %%
import numpy as np
L = np.random.random(100)
sum(L)
# Out:
# np.float64(50.38181102084309)

# %%
np.sum(L)
# Out:
# np.float64(50.38181102084307)

# %%
big_array = np.random.random(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 52.2 ms ± 462 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 523 μs ± 143 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# ----- Minimum and Maximum ----- #

# %%
min(big_array), max(big_array)
# Out:
# (np.float64(4.968660629822708e-06), np.float64(0.999998774586482))

# %%
np.min(big_array), np.max(big_array)
# Out:
# (np.float64(4.968660629822708e-06), np.float64(0.999998774586482))

# %%
# %timeit min(big_array)
# %timeit np.min(big_array)
# Out:
# 32 ms ± 970 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 101 μs ± 7.04 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
print(big_array.min(), big_array.max(), big_array.sum())
# Out:
# 4.968660629822708e-06 0.999998774586482 499896.5477212302

# %%
# Multidimensional aggregates

# %%
M = np.random.random((3, 4))
print(M)
# Out:
# [[0.422219   0.54468492 0.36943611 0.8785713 ]
#  [0.26032629 0.70826747 0.08573911 0.62391099]
#  [0.79226702 0.60080967 0.2308995  0.15691144]]

# %%
M.sum()
# Out:
# np.float64(5.674042819290983)

# %%
M.min(axis = 0)
# Out:
# array([0.26032629, 0.54468492, 0.08573911, 0.15691144])

# %%
M.max(axis= 1)
# Out:
# array([0.8785713 , 0.70826747, 0.79226702])

# %%
x = np.random.random((4, 4))
x
# Out:
# array([[0.21843153, 0.82449543, 0.62136099, 0.4139315 ],
#        [0.09854617, 0.66183696, 0.20506469, 0.96783499],
#        [0.7933114 , 0.08891418, 0.40175081, 0.10298418],
#        [0.01438168, 0.54302377, 0.82471846, 0.776493  ]])

# %%
np.sum(x)
# Out:
# np.float64(7.557079734936041)

# %%
np.prod(x)
# Out:
# np.float64(8.751304691539646e-09)

# %%
np.mean(x)
# Out:
# np.float64(0.47231748343350255)

# %%
np.std(x)
# Out:
# np.float64(0.3091854480213536)

# %%
np.median(x)
# Out:
# np.float64(0.4784776354475398)

# %%
np.var(x)
# Out:
# np.float64(0.09559564126816517)

# %%
np.min(x)
# Out:
# np.float64(0.014381682724845635)

# %%
np.max(x)
# Out:
# np.float64(0.967834994335702)

# %%
np.argmax(x)
# Out:
# np.int64(7)

# %%
np.argmin(x)
# Out:
# np.int64(12)

# %%
np.argsort(x)
# Out:
# array([[0, 3, 2, 1],
#        [0, 2, 1, 3],
#        [1, 3, 2, 0],
#        [0, 1, 3, 2]])

# %%
np.any(x)
# Out:
# np.True_

# %%
np.all(x)
# Out:
# np.True_

# %%
"""                Example: What Is the Average Height of US Presidents?                """
# Out:
# '                Example: What Is the Average Height of US Presidents?                '

# %%
import pandas as pd
data = pd.read_csv("president_heights.csv")
heights = np.array(data["height(cm)"])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 180 168 180 170 178 182 180 183 178 182 188 175 179 183 193
#  182 183 177 185 188 188 182 185 191 183]

# %%
print("Mean height: ", heights.mean())
print("Standard deviation:", heights.std())
print("Minimum height: ", heights.min())
print("Maximum height: ", heights.max())
# Out:
# Mean height:  180.06521739130434
# Standard deviation: 6.837880977107518
# Minimum height:  163
# Maximum height:  193

# %%
print("25th percentile: ", np.percentile(heights, 25))
print("Median: ", np.median(heights))
print("75th percentile: ", np.percentile(heights, 75))
# Out:
# 25th percentile:  175.0
# Median:  182.0
# 75th percentile:  183.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %%
x = np.random.randint(1, 100, (1, 100))
x
# Out:
# array([[40, 74, 73, 27, 69, 90, 85,  1, 77, 12, 54, 26, 27, 65, 67, 11,
#         78, 86, 37, 27, 48, 45, 68, 69,  9,  1, 50, 26,  9,  9, 51, 29,
#         20, 71, 77, 23,  7, 81, 87, 26, 34, 92, 93,  4, 64, 69, 83, 66,
#         72, 22, 96, 84, 19, 80, 18, 65, 32, 33, 23, 62, 45, 99, 89, 36,
#         41, 90,  4, 98,  8, 26, 25, 90, 34, 22, 51,  3, 83, 36, 17, 33,
#         47, 68,  2, 17, 43,  6,  4, 80, 62, 12, 24, 81, 70, 79, 54, 56,
#         60, 25, 65,  1]], dtype=int32)

# %%
print(f"O'rtacha: {np.mean(x)}")
print(f"Min: {np.min(x)}")
print(f"Max: {np.max(x)}")
# Out:
# O'rtacha: 47.29
# Min: 1
# Max: 99

# %%
x = np.random.randint(1, 10, (3, 5))
x
# Out:
# array([[1, 6, 7, 3, 8],
#        [7, 5, 5, 5, 6],
#        [6, 1, 1, 1, 4]], dtype=int32)

# %%
np.sum(x, axis= 0)
# Out:
# array([14, 12, 13,  9, 18])

# %%
x = np.array([[1, 4, 9],
              [3, 7, 2]])

np.min(x, axis = 1)
# Out:
# array([1, 2])

# %%
x = np.random.randint(0, 10, (5, 10))
x
# Out:
# array([[6, 7, 5, 2, 1, 9, 6, 0, 7, 4],
#        [0, 7, 7, 1, 5, 4, 0, 4, 6, 6],
#        [4, 4, 3, 3, 5, 2, 8, 7, 1, 3],
#        [9, 6, 3, 0, 3, 9, 9, 3, 0, 5],
#        [4, 1, 7, 0, 2, 0, 3, 2, 0, 8]], dtype=int32)

# %%
print(f"25 % --> Kvartilini: {np.percentile(x, 25)}")
print(f"50 % --> Median: {np.median(x)}")
print(f"75 % --> Kvartilini: {np.percentile(x, 75)}")
# Out:
# 25 % --> Kvartilini: 2.0
# 50 % --> Median: 4.0
# 75 % --> Kvartilini: 6.0

# %%
x = np.array([1, 32, np.nan, 34, 23, np.nan, 45])
x
# Out:
# array([ 1., 32., nan, 34., 23., nan, 45.])

# %%
print(f"O'rtacha qiymat: {np.nanmean(x)}")
print(f"Min: {np.nanmin(x)}")
print(f"Max: {np.nanmax(x)}")
# Out:
# O'rtacha qiymat: 27.0
# Min: 1.0
# Max: 45.0
